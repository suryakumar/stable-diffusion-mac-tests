# %%
import gc
gc.collect()
# Out:
# 0

# %%
import os
from dotenv import load_dotenv

# Load the environment variables from the .env file
# Loads the HF_TOKEN into the environment, for accessing HuggingFace
load_dotenv()

# If your environment already has the HF_TOKEN key loaded, the above step can be ignored
# Out:
# True

# %%
from diffusers import StableDiffusionPipeline

# %%
import torch

# %%
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", variant="fp16", torch_dtype=torch.float16, use_auth_token=True).to("mps")
images = pipe("An astronaught scuba diving with a horse").images
# Out:
# Keyword arguments {'use_auth_token': True} are not expected by StableDiffusionPipeline and will be ignored.
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
